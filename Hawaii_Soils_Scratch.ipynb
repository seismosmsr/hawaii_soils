# %% [markdown]
# <a href="https://colab.research.google.com/github/seismosmsr/hawaii_soils/blob/main/Hawaii_Soils_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages('sf')
install.packages('raster')
install.packages('exactextractr')
install.packages("googledrive")
install.packages("googletoken")
install.packages("DBI")
install.packages("RSQLite")
install.packages("RPostgreSQL")
install.packages("terra")
install.packages('randomForest')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘proxy’, ‘e1071’, ‘wk’, ‘classInt’, ‘Rcpp’, ‘s2’, ‘units’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sp’, ‘terra’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “package ‘googletoken’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘plogr’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(ggplot2)
library(sf)
library(magrittr)
library(data.table)
library(raster)
library(exactextractr)
library(googledrive)
library(DBI)
library(terra)
library(randomForest)
library(parallel)
# Out:
# Linking to GEOS 3.10.2, GDAL 3.4.3, PROJ 8.2.1; sf_use_s2() is TRUE
#
# Loading required package: sp
#
# terra 1.7.55
#
#
# Attaching package: ‘terra’
#
#
# The following object is masked from ‘package:data.table’:
#
#     shift
#
#
# The following objects are masked from ‘package:magrittr’:
#
#     extract, inset
#
#
# randomForest 4.7-1.1
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attaching package: ‘randomForest’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     margin

# %%
drive_auth(use_oob = TRUE, cache = FALSE)
# Out:
# Please point your browser to the following url:
#
# https://accounts.google.com/o/oauth2/v2/auth?client_id=603366585132-frjlouoa3s2ono25d2l9ukvhlsrlnr7k.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email&redirect_uri=https%3A%2F%2Fwww.tidyverse.org%2Fgoogle-callback%2F&response_type=code&state=a2398300c18c4db2947831a5d96027a3&access_type=offline&prompt=consent
# Enter authorization code: eyJjb2RlIjoiNC8wQWZKb2hYbTdOSV9OVkl1bXFkTVFERnM5ZjZKelNDNm80RENrQjZsY2hobDZFLVc0UWZ1dmMtbzhUV05GellXYjZIUmtmdyIsInN0YXRlIjoiYTIzOTgzMDBjMThjNGRiMjk0NzgzMWE1ZDk2MDI3YTMifQ==

# %%
dir.create('/content/predictor_variables/')

# %%
# Hawaii GEDI data
# https://drive.google.com/file/d/1UY3lxML0Y7bat_9-xEZQQHDkYRcODDZy/view?usp=drive_link
drive_download(file = as_id('1UY3lxML0Y7bat_9-xEZQQHDkYRcODDZy'), path =  '/content/predictor_variables/Hawaii_GEDI_4A.gpkg', overwrite = FALSE)
# Out:
# File downloaded:
#
# • Hawaii_GEDI.gpkg <id: 1UY3lxML0Y7bat_9-xEZQQHDkYRcODDZy>
#
# Saved locally as:
#
# • /content/predictor_variables/Hawaii_GEDI_4A.gpkg

# %%
# Hawaii 250m grid
# https://drive.google.com/file/d/1Jowm2XIdJHrt6N3tGhbLZ81UZZVMqAW8/view?usp=drive_link
drive_download(file = as_id('1Jowm2XIdJHrt6N3tGhbLZ81UZZVMqAW8'), path =  '/content/predictor_variables/HI_island_250_m_grid.gpkg', overwrite = FALSE)
# Out:
# File downloaded:
#
# • HI_island_250_m_grid.gpkg <id: 1Jowm2XIdJHrt6N3tGhbLZ81UZZVMqAW8>
#
# Saved locally as:
#
# • /content/predictor_variables/HI_island_250_m_grid.gpkg

# %%
folder_loc <- '/content/predictor_variables/TerraClimate/'
dir.create(folder_loc)

# https://drive.google.com/drive/folders/1bIbwKYmzP2o6VEAWyLIRmeMQbGFDt-vX?usp=drive_link
folder_id <- "1bIbwKYmzP2o6VEAWyLIRmeMQbGFDt-vX"
folder_files <- drive_ls(as_id(folder_id))

for (i in 1:nrow(folder_files)) {
  file_id <- folder_files$id[i]
  file_name <- folder_files$name[i]
  drive_download(as_id(file_id), path = paste0(folder_loc,file_name), overwrite = TRUE)
}
# Out:
# File downloaded:
#
# • Maui_Mean_Climate_1958_to_2023.tif <id: 1Aglg9-srq187HYR38PFBVrodg3PpcqbE>
#
# Saved locally as:
#
# • /content/predictor_variables/TerraClimate/Maui_Mean_Climate_1958_to_2023.tif
#
# File downloaded:
#
# • Lanai_Mean_Climate_1958_to_2023.tif <id: 1eFkEW2ZRWtMK-IMEpVJ28R3xups_HhOT>
#
# Saved locally as:
#
# • /content/predictor_variables/TerraClimate/Lanai_Mean_Climate_1958_to_2023.tif
#
# File downloaded:
#
# • Molokai_Mean_Climate_1958_to_2023.tif <id: 18SNFZ6VefxYbEEtWl1nXDj8JJFLdFDo_>
#
# Saved locally as:
#
# • /content/predictor_variables/TerraClimate/Molokai_Mean_Climate_1958_to_2023.tif
#
# File downloaded:
#
# • Hawaii_Mean_Climate_1958_to_2023.tif <id: 1pMs5OsTwQ1N3kXO9bb3W-qfhxwcJtzIj>
#
# Saved locally as:
#
# • /content/predictor_variables/TerraClimate/Hawaii_Mean_Climate_1958_to_2023.tif
#
# File downloaded:
#
# • Kauai_Mean_Climate_1958_to_2023.tif <id: 14bpiZID-VOQmsEVeQc9gFHe8JYK7w_ew>
#
# Saved locally as:
#
# • /content/predictor_variables/TerraClimate/Kauai_Mean_Climate_1958_to_2023.tif
#
# File downloaded:
#
# • Oahu_Mean_Climate_1958_to_2023.tif <id: 1zNyLGypMkzHYLoMnOTHhpZmZbil88Xxe>
#
# Saved locally as:
#
# • /content/predictor_variables/TerraClimate/Oahu_Mean_Climate_1958_to_2023.tif
#
# File downloaded:
#
# • Niihau_Mean_Climate_1958_to_2023.tif <id: 1T9RfMhwprSe0YV_ln5Xky9QTYycuh6M3>
#
# Saved locally as:
#
# • /content/predictor_variables/TerraClimate/Niihau_Mean_Climate_1958_to_2023.tif

# %%
folder_loc <- '/content/predictor_variables/SRTM_mTPI/'
dir.create(folder_loc)

# https://drive.google.com/drive/folders/1YKJrZXTo-L4UpvJ0iEGo8yIX6uhoQ9AW?usp=drive_link
folder_id <- "1YKJrZXTo-L4UpvJ0iEGo8yIX6uhoQ9AW"
folder_files <- drive_ls(as_id(folder_id))

for (i in 1:nrow(folder_files)) {
  file_id <- folder_files$id[i]
  file_name <- folder_files$name[i]
  drive_download(as_id(file_id), path = paste0(folder_loc,file_name), overwrite = TRUE)
}
# Out:
# File downloaded:
#
# • Metadata <id: 1GB4d-4-xOOFHbf6R8z8yw5ZVYe4n-Oz-lSM43dpESb0>
#
# Saved locally as:
#
# • /content/predictor_variables/SRTM_mTPI/Metadata.docx
#
# File downloaded:
#
# • Molakai_SRTM_mTPI_Buffer.tif <id: 1WRDZse9NGahMQ4h22bxvsv4XFp10JJZW>
#
# Saved locally as:
#
# • /content/predictor_variables/SRTM_mTPI/Molakai_SRTM_mTPI_Buffer.tif
#
# File downloaded:
#
# • Oahu_SRTM_mTPI_Buffer.tif <id: 1MJEjAuHBeDmvfU_7W4j6RZJk6uLD4TE_>
#
# Saved locally as:
#
# • /content/predictor_variables/SRTM_mTPI/Oahu_SRTM_mTPI_Buffer.tif
#
# File downloaded:
#
# • Kauai_SRTM_mTPI_Buffer.tif <id: 1APv2WFDHdAiwOhBcAw8db-b1NSIlsK1K>
#
# Saved locally as:
#
# • /content/predictor_variables/SRTM_mTPI/Kauai_SRTM_mTPI_Buffer.tif
#
# File downloaded:
#
# • Lanai_SRTM_mTPI_Buffer.tif <id: 1sz3x9fZufpjbtrIpY3ZovhNknmDmkR5n>
#
# Saved locally as:
#
# • /content/predictor_variables/SRTM_mTPI/Lanai_SRTM_mTPI_Buffer.tif
#
# File downloaded:
#
# • Niihau_SRTM_mTPI_Buffer.tif <id: 1JlGaWub7TJ31v7V1GSDQRIq5Mw4wcZx0>
#
# Saved locally as:
#
# • /content/predictor_variables/SRTM_mTPI/Niihau_SRTM_mTPI_Buffer.tif
#
# File downloaded:
#
# • Hawaii_SRTM_mTPI_Buffer.tif <id: 1Qej-icN4NhaYZ8fhhc4bkVXZuD385sl3>
#
# Saved locally as:
#
# • /content/predictor_variables/SRTM_mTPI/Hawaii_SRTM_mTPI_Buffer.tif
#
# File downloaded:
#
# • Maui_SRTM_mTPI_Buffer.tif <id: 1MsRCpuNGuIKInYotrbJ5S-Sagion0wJo>
#
# Saved locally as:
#
# • /content/predictor_variables/SRTM_mTPI/Maui_SRTM_mTPI_Buffer.tif

# %%
folder_loc <- '/content/predictor_variables/Elevation/'
dir.create(folder_loc)

# https://drive.google.com/drive/folders/1XmH9T9xVINZZfPFi39Wus1l7c0SKS4Am?usp=drive_link
folder_id <- "1XmH9T9xVINZZfPFi39Wus1l7c0SKS4Am"
folder_files <- drive_ls(as_id(folder_id))

for (i in 1:nrow(folder_files)) {
  file_id <- folder_files$id[i]
  file_name <- folder_files$name[i]
  drive_download(as_id(file_id), path = paste0(folder_loc,file_name), overwrite = TRUE)
}
# Out:
# File downloaded:
#
# • Kauai_elevation.tif <id: 1SNmoJcKsyKSlG5DVye0c1pHvgWEQ5f1r>
#
# Saved locally as:
#
# • /content/predictor_variables/Elevation/Kauai_elevation.tif
#
# File downloaded:
#
# • Oahu_elevation-0000000000-0000046592.tif
#   <id: 1yRDrfvLTEGECTDQcwXRIxoHmUu3D9LL4>
#
# Saved locally as:
#
# • /content/predictor_variables/Elevation/Oahu_elevation-0000000000-0000046592.tif
#
# File downloaded:
#
# • Maui_elevation.tif <id: 1Or-pj4QiOj8VgMOAPtVjMm_ocbrvGM6_>
#
# Saved locally as:
#
# • /content/predictor_variables/Elevation/Maui_elevation.tif
#
# File downloaded:
#
# • Molokai_elevation.tif <id: 1ae2lpPQngdFx58mRpqt02Z1bQg-Tifen>
#
# Saved locally as:
#
# • /content/predictor_variables/Elevation/Molokai_elevation.tif
#
# File downloaded:
#
# • Niihau_elevation.tif <id: 1L6lodPtr7u70scb-gu_QliaAIyEwYAtc>
#
# Saved locally as:
#
# • /content/predictor_variables/Elevation/Niihau_elevation.tif
#
# File downloaded:
#
# • Oahu_elevation-0000000000-0000000000.tif
#   <id: 1YMV_pXPQjmdam7ucBItWqzFJPPYQK7H5>
#
# Saved locally as:
#
# • /content/predictor_variables/Elevation/Oahu_elevation-0000000000-0000000000.tif
#
# File downloaded:
#
# • Lanai_elevation.tif <id: 1XHgejTU-XLW51qDtVprOcGSeuINa4X77>
#
# Saved locally as:
#
# • /content/predictor_variables/Elevation/Lanai_elevation.tif
#
# File downloaded:
#
# • Hawaii_elevation.tif <id: 116xUvGPbJvJQrFZ7b59EzmcyAPHgKQmN>
#
# Saved locally as:
#
# • /content/predictor_variables/Elevation/Hawaii_elevation.tif

# %%
folder_loc <- '/content/predictor_variables/LandForms/'
dir.create(folder_loc)

# https://drive.google.com/drive/folders/1PkUR4GK50wC6Kgrvyy-d6067ypdX1dkx?usp=drive_link
folder_id <- "1PkUR4GK50wC6Kgrvyy-d6067ypdX1dkx"
folder_files <- drive_ls(as_id(folder_id))

for (i in 1:nrow(folder_files)) {
  file_id <- folder_files$id[i]
  file_name <- folder_files$name[i]
  drive_download(as_id(file_id), path = paste0(folder_loc,file_name), overwrite = TRUE)
}
# Out:
# File downloaded:
#
# • Landforms_Buffer_2000m.tif <id: 1HMIkKM_02cVNWaB7-IYwnd414Wg5acnK>
#
# Saved locally as:
#
# • /content/predictor_variables/LandForms/Landforms_Buffer_2000m.tif
#
# File downloaded:
#
# • Kauai_Landforms_Buffer.tif <id: 1oRmeE1kg5GswFcDdUaGU5jnui9Y2DpR3>
#
# Saved locally as:
#
# • /content/predictor_variables/LandForms/Kauai_Landforms_Buffer.tif
#
# File downloaded:
#
# • Oahu_Landforms_Buffer-0000000000-0000065536.tif
#   <id: 1PcZoQe0l8WLgSagiWWUpTmWmmHmGnIRx>
#
# Saved locally as:
#
# • /content/predictor_variables/LandForms/Oahu_Landforms_Buffer-0000000000-0000065536.tif
#
# File downloaded:
#
# • Molakai_Landforms_Buffer.tif <id: 1ZBdccF_ELdIApV0SkAv2ZfWsZ0a0ae1f>
#
# Saved locally as:
#
# • /content/predictor_variables/LandForms/Molakai_Landforms_Buffer.tif
#
# File downloaded:
#
# • Niihau_Landforms_Buffer.tif <id: 16jkuVWQ_BIjLBJiTeZeHMj3Z_FCJ4ttm>
#
# Saved locally as:
#
# • /content/predictor_variables/LandForms/Niihau_Landforms_Buffer.tif
#
# File downloaded:
#
# • Hawaii_Landforms_Buffer.tif <id: 1qBNjiXKd-JJ8CICZvVTo42kkKjBNhYMT>
#
# Saved locally as:
#
# • /content/predictor_variables/LandForms/Hawaii_Landforms_Buffer.tif
#
# File downloaded:
#
# • Lanai_Landforms_Buffer.tif <id: 1LU4LHzgkHHCmdOfWccniRJ8d0225AFu1>
#
# Saved locally as:
#
# • /content/predictor_variables/LandForms/Lanai_Landforms_Buffer.tif
#
# File downloaded:
#
# • Maui_Landforms_Buffer.tif <id: 1v1bBZWsHDYWZfhfGby_wWylkSrVQaqx9>
#
# Saved locally as:
#
# • /content/predictor_variables/LandForms/Maui_Landforms_Buffer.tif
#
# File downloaded:
#
# • Hawaii_Landforms_Buffer_2000m.tif <id: 11H593mq88YS_NQ39yJBkm4hf77exgb5Z>
#
# Saved locally as:
#
# • /content/predictor_variables/LandForms/Hawaii_Landforms_Buffer_2000m.tif
#
# File downloaded:
#
# • Oahu_Landforms_Buffer-0000000000-0000000000.tif
#   <id: 1AzX2SjqLBZnxIfRwNAjzXQQuQGujN24p>
#
# Saved locally as:
#
# • /content/predictor_variables/LandForms/Oahu_Landforms_Buffer-0000000000-0000000000.tif

# %%
folder_loc <- '/content/predictor_variables/LandSat_composite/'
dir.create(folder_loc)

# https://drive.google.com/drive/folders/1NzvurSghdEJdX0UsfdyuOcOyh6n3jUDo?usp=drive_link
folder_id <- "1NzvurSghdEJdX0UsfdyuOcOyh6n3jUDo"
folder_files <- drive_ls(as_id(folder_id))

for (i in 1:nrow(folder_files)) {
  file_id <- folder_files$id[i]
  file_name <- folder_files$name[i]
  drive_download(as_id(file_id), path = paste0(folder_loc,file_name), overwrite = TRUE)
}
# Out:
# File downloaded:
#
# • Niihau_LS_composite_2012_2018.tif <id: 1yphCVOxcRgBOKdhvOOQunCnObkHhPWWx>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Niihau_LS_composite_2012_2018.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000000000-0000035840.tif
#   <id: 1Tyc-6B7SqE1nMRBDbSzNP9KvoItaogpC>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000000000-0000035840.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000008960-0000026880.tif
#   <id: 1yaE46GTtCsjXAhqK43HzMHgfMicRjMnK>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000008960-0000026880.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000008960-0000035840.tif
#   <id: 1sxPsCuwNjHyfO2Sxit0jVfG_jai9IJWR>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000008960-0000035840.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000008960-0000071680.tif
#   <id: 1h048N56sL8ONS__dq3Rvv5AcoqXj5OW5>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000008960-0000071680.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000017920-0000044800.tif
#   <id: 1Am-dtw1x7OaH8wFAoSNjl9ZuknVezhJM>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000017920-0000044800.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000017920-0000053760.tif
#   <id: 1GyLpxk5ukusI1n5Ya9XObOxgaP84J-Sd>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000017920-0000053760.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000026880-0000008960.tif
#   <id: 1xx19M_Qj9I0MaNGswJnTpSxWN_u7obGZ>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000026880-0000008960.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000026880-0000053760.tif
#   <id: 1GYZbsuuHnIppFck45JbPTeuL1yjpZurC>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000026880-0000053760.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000000000-0000053760.tif
#   <id: 1YM8FG8GlFzOu5eTzsu8yuzQSxK8tWoHn>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000000000-0000053760.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000000000-0000071680.tif
#   <id: 1V7Tmq9NV1KfuzEf8tYl-PwSfgffdVcBd>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000000000-0000071680.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000017920-0000000000.tif
#   <id: 1VYpYFZohAipbD_Z06HoIsQr11JoGHV3Q>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000017920-0000000000.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000017920-0000017920.tif
#   <id: 1ZY5VU3dqQEzST-a_Y_N5psClMkj0LhS6>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000017920-0000017920.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000008960-0000000000.tif
#   <id: 1bYSagWcYRfVwL8WnD7RDFYbL8SWM3709>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000008960-0000000000.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000008960-0000008960.tif
#   <id: 1MmA9-7zA4WYeUxfrCIBxOR6a8dthU1mu>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000008960-0000008960.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000008960-0000017920.tif
#   <id: 1kyc-1KtcvgapgBlnwC_jbblvvUKTd2XI>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000008960-0000017920.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000008960-0000053760.tif
#   <id: 1SBJ51492ILEcwYJF4lCbsTDKekGeOJLX>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000008960-0000053760.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000026880-0000000000.tif
#   <id: 11Q2dyTnizWzqOtDqYeehdJJvwEqz5pCG>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000026880-0000000000.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000026880-0000044800.tif
#   <id: 15wOx4LbskGPYH2MBokQ2g210Z69OR10V>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000026880-0000044800.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000017920-0000008960.tif
#   <id: 1tc5SGvkmD3xnqTQRgJYwSDIO6XizPZsQ>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000017920-0000008960.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000017920-0000071680.tif
#   <id: 1RwYELhXCf7GH4SmJjxmKaJrXDyyfC-o9>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000017920-0000071680.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000026880-0000062720.tif
#   <id: 198oPEMLWxG_yw81FiQZPX_QYynTnTCNU>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000026880-0000062720.tif
#
# File downloaded:
#
# • Hawaii_LS_composite_2012_2018.tif <id: 1EJWKN1fQFk10ODucJaJ-Y85kwAIAkXdO>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Hawaii_LS_composite_2012_2018.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000026880-0000035840.tif
#   <id: 1Z0yJMivrU2OTyml7vilXcHAMtd2VRWgK>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000026880-0000035840.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000026880-0000071680.tif
#   <id: 1EYTgSBFIkoImi8KSh3k3dA7Q-RKgvViS>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000026880-0000071680.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000026880-0000026880.tif
#   <id: 1xxTL6LDIVpeqV5drANGRBrmTOP-R7OJL>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000026880-0000026880.tif
#
# File downloaded:
#
# • Molokai_LS_composite_2012_2018.tif <id: 1PAdKrn74OPn0DABilto8YIJNdOBOBBKE>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Molokai_LS_composite_2012_2018.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000000000-0000008960.tif
#   <id: 1Xhd-_PQ6u9UqwNFx5xFncC5OPCPFm5pd>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000000000-0000008960.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000000000-0000017920.tif
#   <id: 1P-i9XcN4qsnfiy26vyORkmuzXIpWrI-D>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000000000-0000017920.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000000000-0000026880.tif
#   <id: 1x1OPChnSFwnKTsOqrBPopbJQKJTTmabl>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000000000-0000026880.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000000000-0000044800.tif
#   <id: 1ig_nM95kDvLr8dgYlp0PQyx65YAYkAbI>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000000000-0000044800.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000000000-0000062720.tif
#   <id: 1qqDjZP0D1X87I02GNyy1JxhCC1p9EU-e>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000000000-0000062720.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000008960-0000062720.tif
#   <id: 1beEDV7FQzjHqHVcGwPANRnSX-irJkYJg>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000008960-0000062720.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000017920-0000026880.tif
#   <id: 1R_TWiUhuLGchd-MWbL19NaY5wUSgNUwp>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000017920-0000026880.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000017920-0000035840.tif
#   <id: 1qzaZk95zg4oCVYBoC6WX2yjC_szZlejJ>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000017920-0000035840.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000026880-0000017920.tif
#   <id: 1M7xCSw8mfrToCz1W8hyk3bo2J4jYxLfn>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000026880-0000017920.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000000000-0000000000.tif
#   <id: 14PMYBdBOSiJLSmW6jNmf0U5UO_87s2GM>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000000000-0000000000.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000008960-0000044800.tif
#   <id: 1hwLxZy9U_FN0n7OYaFc9PiyeVQew8j_b>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000008960-0000044800.tif
#
# File downloaded:
#
# • Oahu_LS_composite_2012_2018-0000017920-0000062720.tif
#   <id: 1zt-5ulXvabmU1WZTGG9_B038VL5l1jVC>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Oahu_LS_composite_2012_2018-0000017920-0000062720.tif
#
# File downloaded:
#
# • Lanai_LS_composite_2012_2018.tif <id: 1CdXltYRNLCwcbZio9rHAMcN2Gvzl8XNM>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Lanai_LS_composite_2012_2018.tif
#
# File downloaded:
#
# • Kauai_LS_composite_2012_2018.tif <id: 15dHlF672gbMBoAbVs8L71k5KVQsDq2m3>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Kauai_LS_composite_2012_2018.tif
#
# File downloaded:
#
# • Maui_LS_composite_2012_2018.tif <id: 1SPz_lbxHhtjwIBO7qFuOvpLNHqhrR3kv>
#
# Saved locally as:
#
# • /content/predictor_variables/LandSat_composite/Maui_LS_composite_2012_2018.tif

# %%
folder_loc <- '/content/predictor_variables/DynamicWorld_landcover/'
dir.create(folder_loc)

# https://drive.google.com/drive/folders/152pjTArpwlDVGjXFoSU9bmo1BDSKdCqq?usp=drive_link
folder_id <- "152pjTArpwlDVGjXFoSU9bmo1BDSKdCqq"
folder_files <- drive_ls(as_id(folder_id))

for (i in 1:nrow(folder_files)) {
  file_id <- folder_files$id[i]
  file_name <- folder_files$name[i]
  drive_download(as_id(file_id), path = paste0(folder_loc,file_name), overwrite = TRUE)
}
# Out:
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000200448.tif
#   <id: 1d1budUOMeLAnuM2sc0XRwNaGJDVYD6mi>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000200448.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000096512.tif
#   <id: 12WZZsotfizLogT8LNfk5xnd8B_SwxmX7>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000096512.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000193024.tif
#   <id: 1LYpsLuD3I41nw7dzn2iragALgzqlSDfe>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000193024.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000200448.tif
#   <id: 1FaGqlWwDEWImhMgu8PRwC_YBoKOGkFZP>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000200448.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000044544.tif
#   <id: 1dcJxjczVyEa8VRoSNy24NhVoMkm0BH7w>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000044544.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000163328.tif
#   <id: 18n_NynkIV-x_Mfa6EHkqZYcrbuYzKCsi>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000163328.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000200448.tif
#   <id: 1X7CoHwWNXLrOl3_yllo1jYNpA21EDTDw>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000200448.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000066816.tif
#   <id: 1PY6PReuPFGZhxffX1lA40w4vuW_oqY5K>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000066816.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000103936.tif
#   <id: 10TPvbFq2Ked5DR7z3B53C0TFPK-XZyJY>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000103936.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000148480.tif
#   <id: 1CvWuga_yrFs2x5iKI8CizsxUJdwTgSgo>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000148480.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000014848.tif
#   <id: 1xmG6ZksPZZ1RSg8yR06Atnh16pShwW3N>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000014848.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000022272.tif
#   <id: 1PnZdiDNayT66k6K6H3F7C0spr1PmhTQ9>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000022272.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000185600.tif
#   <id: 1Mfr_m2wwVsNhJ-ixw5h4IafABMx34Gok>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000185600.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000230144.tif
#   <id: 13sPnI2KF6AbvVThqo52IODMi21_xklEA>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000230144.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000133632.tif
#   <id: 1ljtpYzUmN1G_aHtqA2QZcISxu6rUNEEy>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000133632.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000066816.tif
#   <id: 1yYO_xsEeVM49MHSdfjO40iPNQBtqPvuv>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000066816.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000163328.tif
#   <id: 1XhyLn26IoYl_R2zpdPRxYTCY0MzsLq5g>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000163328.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000193024.tif
#   <id: 1RaXdu5x5GETN5x9O0S4oPQzCIqmo3kqX>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000193024.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000230144.tif
#   <id: 1Kjfx2GHYQEuSQixuKg9ifOlFixsL7KK8>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000230144.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000118784.tif
#   <id: 1pyzf95s9drdhsCxERzaqa3c2G7bzQ2fN>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000118784.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000148480.tif
#   <id: 1PN7KpKmK_i53EmMwmzaC0Sl_LmgLUM20>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000148480.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000222720.tif
#   <id: 1t2E_WmfgH_5hg2kkPQXdOgQ6-tl4bVjL>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000222720.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000014848.tif
#   <id: 1J30BISuQIUqEB41VSFr6U9Oqlkc4cq3C>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000014848.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000103936.tif
#   <id: 1LGf6EkEpIOpQCp3CZ_yPb9q48liEZzCU>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000103936.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000148480.tif
#   <id: 1pPrjAXTRquFK_PMJ_kQmxmbWE_zneZZG>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000148480.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000170752.tif
#   <id: 1yy1GiJY32sL9hICSV29fmVsbvq3V7Hnl>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000170752.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000230144.tif
#   <id: 19FuR7du29_3ardEMZpUvOAr0ogyeUdo->
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000230144.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000000000.tif
#   <id: 1v3yZEeIeXIktGhfjcvcwBoujcMvtf4Qk>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000000000.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000074240.tif
#   <id: 1Tnsd4PZQSPdEbdX3VtH-_doNBWuyWMtl>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000074240.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000133632.tif
#   <id: 1WWIQ7mgFTapiCZhUHQd6r_V04NtRRc41>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000133632.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000207872.tif
#   <id: 1641W8p6RmMuOktucr392EbYxWYp7m0Jx>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000207872.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000230144.tif
#   <id: 1JYv9lOHuHkGLSTk-TgHC7bce9eNsTKfa>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000230144.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000014848.tif
#   <id: 1ji7TnVfn9l-JrTwhl0mV99IeHAVfDn45>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000014848.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000059392.tif
#   <id: 1o-EW3cNRmzUEeQkFh_44EOZ8B_4zkBxJ>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000059392.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000207872.tif
#   <id: 172Q5a9dQWLWCjFjDR7Dmt1FNxUhwFyb4>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000207872.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000000000.tif
#   <id: 1UXo1lTjf6G7T9bhcTRzY8e73gji5a4zd>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000000000.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000014848.tif
#   <id: 1bqD825J-bUuc_X6OJULmM5JqTf5hIJXw>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000014848.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000074240.tif
#   <id: 1Lq1w99o5QM4YB1pTlMtGr9utSxyFktyE>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000074240.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000096512.tif
#   <id: 1AGOaIgZoij63XtH42h3c42f1wtgAR6Tb>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000096512.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000007424.tif
#   <id: 1Vzz8ZhC78WFzTND-r5Q1czQd_3JRR_Fw>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000007424.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000096512.tif
#   <id: 1Fe_Go9JQXi9u7lLPofCYftXEyezNw8JZ>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000096512.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000037120.tif
#   <id: 1FgFxCe-kQ43ZjgagYpRobWHWQYyRi7Bd>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000037120.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000044544.tif
#   <id: 1s7PlchUaATZvH_YjimhYFyFhMJEjRW66>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000044544.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000178176.tif
#   <id: 18wbjLRxKvxdCccnVCRQ3D7npcQx5-QQ_>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000178176.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000007424.tif
#   <id: 1NT0m4AjaXVs6PlLnEFluvZpEmXpcp8d->
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000007424.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000029696.tif
#   <id: 1R2ZhmipzLJK61xx0b71LJzYoEQ3FQj_W>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000029696.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000059392.tif
#   <id: 1qjInBd-cIW4hhrnTtk4oqaUQh2-voS0D>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000059392.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000141056.tif
#   <id: 1j-oH2YLYPsxbnCpmmX08EUQnCVUDaxXh>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000141056.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000148480.tif
#   <id: 13NwlOLJ7XSJYc1gAx4TKoVtZZr3LEzaf>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000148480.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000163328.tif
#   <id: 10BqGnyiOOeIbBaJhDH2a3QCL1aK32rVo>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000163328.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000215296.tif
#   <id: 1NFjMiA9aJfhqJo0d5CuOKDifq2CQFAda>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000215296.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000215296.tif
#   <id: 1vw5g3RJyvTmOO7hQGNyM8807MPVkyBKz>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000215296.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000096512.tif
#   <id: 1v5BuOG0-SFkr0NbcLX-DkBFJzKSGT0JE>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000096512.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000141056.tif
#   <id: 1hAWswB1ttAUoHS3tN-6T7l3doNppUgjt>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000141056.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000170752.tif
#   <id: 1quHj9HpijJECWBrSX-u_st2uhC0Z8o5m>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000170752.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000178176.tif
#   <id: 1fMgfVRvggxAQh28tOuZpdLdqPMuQxAuM>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000178176.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000044544.tif
#   <id: 1Vj2Gcl0dKgHwxjDqCGJ4BTxyXx7HJa3B>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000044544.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000096512.tif
#   <id: 1_ZPYM2yXqbeHvw4EW8pMZZfGWnvia8aW>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000096512.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000170752.tif
#   <id: 10G7KqiHVxV4G9qltKEl9DoJbO2wyYq2w>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000170752.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000200448.tif
#   <id: 103V4VoaOygDYCs0kUhf03DD4X7oXxrIJ>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000200448.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000222720.tif
#   <id: 1XUYqWlin60Hxsjq8tM6J7i9o89kIsIoN>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000222720.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000089088.tif
#   <id: 1OHcKym9_G-BwNrTD6ZVxI5ozMQzuonPY>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000089088.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000000000.tif
#   <id: 1fQpMvE_YGlpkZbaaiY-6sC0K7KKmHi7S>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000000000.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000007424.tif
#   <id: 13dFr366pLKp1paa1xS9pl1j9ry9Xv-23>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000007424.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000126208.tif
#   <id: 14IDIz1vJqtkRbsHhkG6hQX8QUBmvmNp7>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000126208.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000193024.tif
#   <id: 1FfT7s1t0CQ4iBcu8fF0RJYXe9RKxtfij>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000193024.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000066816.tif
#   <id: 1K1hjg40OHKlyX5fjaLFLXtFNy_nYSAq8>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000066816.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000096512.tif
#   <id: 1yT-Vrd6x4kvaONBg9LE98vaEbNyoeZi3>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000096512.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000155904.tif
#   <id: 1pJ0yJGUVt0hb8UaeZn5I-4OGguhDvoUj>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000155904.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000178176.tif
#   <id: 1YgJNrpDApEruvTCRwN7LAqHPKsvZf4Lz>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000178176.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000185600.tif
#   <id: 19DtTLjlI_AVs4xBGyW5wjulRZljoOCC9>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000185600.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000007424.tif
#   <id: 1qRNNPPBQL5AXOS868grbkl9wOfcOPRBn>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000007424.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000037120.tif
#   <id: 1MR_EoByzZQaQBFXDTH3Pncf5eCN0CP6V>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000037120.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000089088.tif
#   <id: 1K3KKn6GQhq1RKZaXwqaxCtl41QacTtv9>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000089088.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000126208.tif
#   <id: 1ZPIc0k_mHJrM0bvOEw6m9fLBiTcdBY39>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000126208.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000185600.tif
#   <id: 17PDGMJclETmCZ9LOPAZHq0YoLSzGgz3G>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000185600.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000089088.tif
#   <id: 1PJwDHGTcVmmdlun6VyyURvChaIevGG4W>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000089088.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000103936.tif
#   <id: 157NXte2eNUc_QAL7XNVgcDnq6LKlqFaO>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000103936.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000141056.tif
#   <id: 1DbLIcbvCpOlbamw5PvTK3xPwCtU_7A2k>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000141056.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000215296.tif
#   <id: 1RypFUkvhBVIsAdyPrv6DOaSKTIIU8aqo>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000215296.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000014848.tif
#   <id: 1a-xJzJJxj-PBQmUEI62jAKT8Irtrh4dx>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000014848.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000014848.tif
#   <id: 1-HW84lQXx9vUIdqpvKoT3WmM0x1EZdFS>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000014848.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000230144.tif
#   <id: 1aW6kU-WHZYr2lOJdEjjyU6QolBr_IkOa>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000230144.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000051968.tif
#   <id: 1F6LTT41FMzsKrpt-fowYhJ0kOkDc--mD>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000051968.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000081664.tif
#   <id: 1YZlWdQYK5BpZkWzHA8cPAaoTL_BgxQlk>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000081664.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000126208.tif
#   <id: 1tT_KokLsp1zV5Qmb_NSuoFmA2DPxVZtN>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000126208.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000178176.tif
#   <id: 1n9W0vIkHe_610qwag64rdOE5TLbY5cvM>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000178176.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000193024.tif
#   <id: 1skST2NlpT6hGLGYXT520rOBIX9H2k0oo>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000193024.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000044544.tif
#   <id: 1tFYvwEbuoxCqtwWywjufkw3sZA4jXdZd>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000044544.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000089088.tif
#   <id: 13sYKD2RxdnvFPkjqAwimEZLwwigw9VL9>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000089088.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000111360.tif
#   <id: 1LuWYH1dPMD3C5z25o9B_nDw6u2rgQzai>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000111360.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000118784.tif
#   <id: 1m6_eaZPQ2_h2FWs8TDQJ9jmF-cXH1eai>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000118784.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000126208.tif
#   <id: 1QjqC156TEShbf2h-5R37Rc6gKvXF5Toi>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000126208.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000163328.tif
#   <id: 1Q6PJvW5WO-t90xuVPgy9oyJsY1z3boyJ>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000163328.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000178176.tif
#   <id: 1uLSnFvBE4sSrZ4Fh9MO3vXP6Q5IG6NIX>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000178176.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000193024.tif
#   <id: 1EQ8iaFP8fd4fcKPvl3F4d2roH2_weini>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000193024.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000044544.tif
#   <id: 1fN7irxtrdZBX1PSSkRcA8n3X-jfvgWnb>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000044544.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000103936.tif
#   <id: 190rSvpiMo9EmTR_n_S7S76ZEtSxC428g>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000103936.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000222720.tif
#   <id: 1X7gFCHceUrlLgxPaLIszJrv-__33kaq4>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000222720.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000022272.tif
#   <id: 1tyz8g4GmT12Xp9kUMe4MTfc6CnE1Y60a>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000022272.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000089088.tif
#   <id: 1juOZRCXo-LFbNGAXOwnnVt0IBGmKzPAU>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000089088.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000148480.tif
#   <id: 1_KRCTcSsbkduklj5qQCl0UuVzHrT0SzQ>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000148480.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000155904.tif
#   <id: 1JkfXqbpghLtcgHB536tHP2V1Ojd_1cdB>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000155904.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000185600.tif
#   <id: 1cgOBsRUQLjot3jR5xAIEkDPY-GYNO2oJ>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000185600.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000007424.tif
#   <id: 1pxFNKwGsMVacKhvO9eqPYc0puiVQVCgq>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000007424.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000081664.tif
#   <id: 19s8eVJQ3HXUHInlFcRXoKbd7Bnrw6FuT>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000081664.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000029696.tif
#   <id: 1YSuMfjU5pAfdoNa0msEQkBfhdsOIMo69>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000029696.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000037120.tif
#   <id: 1MFFHdkFn2jf9TT6B0D5GDIAnxo3lv7Bp>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000037120.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000096512.tif
#   <id: 1YleDpF7ldTHZpR5DTkOjpqtbPTHAfWGZ>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000096512.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000133632.tif
#   <id: 1M9fHm81MJxrgUPT5YM5PPTZg6GXNuOmb>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000133632.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000185600.tif
#   <id: 1-tNFQTUsrOvszAhVy-yhCHpKA68uDUGx>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000185600.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000014848.tif
#   <id: 1p3VfJElCJhngC4o2VCKp1FE0PhVlhxsd>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000014848.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000081664.tif
#   <id: 1yPbRgiPQXUdp2gr879ItJRKgKfoxGQKJ>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000081664.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000215296.tif
#   <id: 1t8pJRPuGfitPIbNeFVXMlWbAnAulfstt>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000215296.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000022272.tif
#   <id: 1gM23uDc8p3nNc2BxVgvN2bh2m4w38kV4>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000022272.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000066816.tif
#   <id: 1Zu4hMLMi-Cjy9k95RzxUeNbfkiB0mOIo>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000066816.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000118784.tif
#   <id: 1MNjhmjMxHgOegpZb9wvWCD0_R1rGtscJ>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000118784.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000163328.tif
#   <id: 1m-4_MExfyQexUE6WtIttlWE7XNDc-nAr>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000163328.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000170752.tif
#   <id: 1WrnSkATz9nk_zupVTu7dmB1OIuR8WW-l>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000170752.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000007424.tif
#   <id: 1Y1QzWL1sUZMddpTW4q0G_vghPv9HRO7D>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000007424.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000126208.tif
#   <id: 1v2KyzBp72xz6sfeMu1uRrwBe-OHyrd4K>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000126208.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000163328.tif
#   <id: 1Lm5Pio1cezo-zOqvlQXSWID3UJeOHwi9>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000163328.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000118784.tif
#   <id: 1RmsY42D1uK2WFLqKCmMS-odRjogkgcW9>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000118784.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000155904.tif
#   <id: 1-QjEpfS-UVcM8m5FO_O9lnMmuihaFF5T>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000155904.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000178176.tif
#   <id: 1qBlVXPyMr7QCBjOGq7zTKde-QKjIXMLk>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000178176.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000185600.tif
#   <id: 1zIzum_1PKhdWCdmvQNj3DVmpoR-sgjQM>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000185600.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000000000.tif
#   <id: 1CMzkh3cN7C_wHzOJH58E66Rce4_ScT4v>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000000000.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000059392.tif
#   <id: 1p903QhyChS1cLFQw3hBs5PDr0HoIpwFS>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000059392.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000074240.tif
#   <id: 13w_rWMVmi9Awfe4kt0teVdRd72uxs6Xp>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000074240.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000133632.tif
#   <id: 1UVrUKT0ec2tuNaqDMenVRnNCQlwoaD_p>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000133632.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000155904.tif
#   <id: 1TASFAX8EtLz3SILE5x8Z3HaKuEZBX9Xf>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000155904.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000170752.tif
#   <id: 12nMbs0nj-1dBvReLI9W4aMSpJoXzzD3s>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000170752.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000193024.tif
#   <id: 1Jt2pv754nBHcxVL457pXj4qtkbZIbTP6>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000193024.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000118784.tif
#   <id: 1LFOJ_eXBxsw0k7Ak9gOFaaVJ7Pizsy3C>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000118784.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000000000.tif
#   <id: 1dYWnux0Xymq9M_1De3PImTZ2WJ3q_0Qq>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000000000.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000148480.tif
#   <id: 10SAINBJ7-WtrlRSowWN75kkKC5Pi5S-h>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000148480.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000155904.tif
#   <id: 10dxD7OedAzRozHcdRvm9IoRFMV72NOJR>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000155904.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000185600.tif
#   <id: 1zkEP2lI45OlPuUACje89N_dcHcxerEP0>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000185600.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000207872.tif
#   <id: 1OWlXMkqXwPZoBD4pCOd509G58nievFOs>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000207872.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000222720.tif
#   <id: 1q2HFg0D-By5pP-sCg5QKBdJz03-K9gEv>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000222720.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000230144.tif
#   <id: 1VyuVLyHcraOaAwPFE9A8ncymg9zsGON->
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000230144.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000081664.tif
#   <id: 1EHn_NZdx2uwn6LR52YYUewCXjebddyRc>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000081664.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000089088.tif
#   <id: 1GgRkS_L5QGInymoU2Xq2_WLHsUi9mY4g>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000089088.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000215296.tif
#   <id: 1Cow0lTf1WQHzzUgiGf9SttT2Ansf9Fd8>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000215296.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000230144.tif
#   <id: 1kA2cCPTRKcWMtqPtD4XcxI51jcL6HLkW>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000230144.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000111360.tif
#   <id: 1LKpOSYcT_u_MUQ3-gz268foOLey_d2Zm>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000111360.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000126208.tif
#   <id: 162UaKMH2Pk17kTWMO0jOM4i-8vi7Xf7e>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000126208.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000163328.tif
#   <id: 1HhjuH3p94Sr5gc85i3Mcan1piDKeFrlT>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000163328.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000178176.tif
#   <id: 1-_NBOF93F6wemwG6upklAtaxUBWBGHLQ>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000178176.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000037120.tif
#   <id: 1fJiWjlAxfj4DS549t-SSrPuirsB30H-T>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000037120.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000051968.tif
#   <id: 1EkrOKBFKxvQOn0YuzMrV7UFe_VDUPM7Y>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000051968.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000074240.tif
#   <id: 1tIszTS5pMTy6O7taPls36ffQmp-ODiUu>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000074240.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000163328.tif
#   <id: 1gsrpa61We2sBBeAxOfzsQ8k_TFCnRcol>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000163328.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000207872.tif
#   <id: 1MzXy4O0mvUuywrJtVG92tbEbtVFnAc_b>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000207872.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000066816.tif
#   <id: 1PIErF4O3OTVM7kOtXRIQ7OZo5lfnra4l>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000066816.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000074240.tif
#   <id: 14BYoMOCN-UF3GJnd-Xc5ZqObmavwf4kj>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000074240.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000163328.tif
#   <id: 1txYoh-v9KNuto_HH_aczfPq-MCRJT5uR>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000163328.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000029696.tif
#   <id: 1TKYNHHyh4QR7cEu4wjyDDY6U_kvpyiOO>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000029696.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000133632.tif
#   <id: 1W0YdlWg7eATh8s8W5qjhyj7w4B3W2gw3>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000133632.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000215296.tif
#   <id: 1JE9RhZn6CtKD8F_AbXA5MvBQj0u0t-IY>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000215296.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000022272.tif
#   <id: 12s3cmBlHNuLTGXyRGebRzCdtjpXpV0b4>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000022272.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000044544.tif
#   <id: 10y9-Sm8CZbS0Xo_2TVSR8n9XT6S8wIDn>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000044544.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000178176.tif
#   <id: 1MG-FgYxZO0l3ndtJj_Jc7LlOUom0m4G2>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000178176.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000185600.tif
#   <id: 1Xjr47Gdz9juI83GzN6W2L7j6y1nVpakr>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000185600.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000222720.tif
#   <id: 10H81Lp_1v8eZACbcuArF4MaV_lP6vlye>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000222720.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000089088.tif
#   <id: 1-ZcWQt-5Ew1sxRQ_09nNXjEVT4vezvHU>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000089088.tif
#
# File downloaded:
#
# ...
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000207872.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000141056.tif
#   <id: 1YvLJTZeNHSqx7jhHsKJUGi_QOcwwQ7JZ>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000141056.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000074240.tif
#   <id: 1iRSfAjT21UZTjJWPTnondaeZRXI1vT7N>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000074240.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000103936.tif
#   <id: 13D1mlPk9iA-fm4sZWnpWbKlFUCz37xXx>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000103936.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000037120.tif
#   <id: 10ND8szXYsoIGMdH_EzuMDGQYuWn_ELCu>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000037120.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000051968.tif
#   <id: 1V7AT-_2vCucEq_oN1nuLaI2iTXulmvVL>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000051968.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000029696.tif
#   <id: 1pl1s9Wa-9magRDx7aOb26oLSovK6-IfJ>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000029696.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000118784.tif
#   <id: 1GltzWQjp6DfPS1o1tQ-UqgzL5TgAE6PX>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000118784.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000051968.tif
#   <id: 1WfGJ0r8Ec8PIew45mOjv5VspdndP1yvT>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000051968.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000133632.tif
#   <id: 1kO8CnFztubB4Y1xkED1Wu7oy_QmEsNrE>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000133632.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000207872.tif
#   <id: 11M9IIVPT0WR2rssPnGARD9n2xq1lmz7x>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000207872.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000059392.tif
#   <id: 1mlRTtoIXJUETETiQpMNZ_vPIGesJwecX>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000059392.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000133632.tif
#   <id: 1gvsYobtrUp0R7aqEZxdu73P-7JDoZuB8>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000133632.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000170752.tif
#   <id: 1eAHczhmmkdV7D5p_nNCn6FRxt-46YiaR>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000170752.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000051968.tif
#   <id: 1a5VC9hItgNLfV1O93w6yqlp1MccRMUyB>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000051968.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000118784.tif
#   <id: 1u1g-0VhgjLZX-AL1XvKqK1UXb1rR7JJt>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000118784.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000141056.tif
#   <id: 1ES8TsURnBcbxMB4gUsbreSSpfHAIchmB>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000141056.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000007424.tif
#   <id: 1JCU1_VGkhN_QH6F7EkwknUibOjgME9Ps>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000007424.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000126208.tif
#   <id: 1EXEIyA_WgAfk5OZ1f1XADPh4h3pYENgV>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000126208.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000170752.tif
#   <id: 1EGKCe8JXq8164-3r2Y0rfmYqjpeAGHMK>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000170752.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000148480.tif
#   <id: 1HWJjhzjBUFmwfmROTCX9vDoJhU3NTvta>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000148480.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000155904.tif
#   <id: 1inWkXqZCYjYqDclIxVaGJ9ePCxubQzpe>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000155904.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000222720.tif
#   <id: 1v8YeNTdF7mQ6P51coucqDlpCeBYIlSPY>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000007424-0000222720.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000133632.tif
#   <id: 1YzevtewRlxjdCOQMtdYdhXiUUYVjPBYn>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000133632.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000148480.tif
#   <id: 1Y_0JzNeqgGMelo6QDFHw4jCSxBGBE2L3>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000148480.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000155904.tif
#   <id: 1oqnBTMSjEcbBxVwQnIBcYzCZWlWM69Rc>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000155904.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000170752.tif
#   <id: 1R2sRorsYJ7F2I8ffWsHWq1y2GxlnqqQv>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000170752.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000193024.tif
#   <id: 1bzUfRzxNEVEKrly38VvxvzozgEGFN2oh>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000193024.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000029696.tif
#   <id: 1AwTU4NQDOdJBZw4A7tUNDdMGoqFalBEE>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000029696.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000059392.tif
#   <id: 1tknubGTozofsOiF5At1b_p5B2sUVlwkV>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000059392.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000066816.tif
#   <id: 1xmX6q5qbq8Y0g4pbGY7tbvAKvWXg8Jv6>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000066816.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000081664.tif
#   <id: 1UJ7_BWGJNmKeE3VTTuncLTCx_s0kQQ4b>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000081664.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000193024.tif
#   <id: 1pHOsmbJYUz6qp_AL4jSIcZWr6j1yQENw>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000193024.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000222720.tif
#   <id: 1OMyaThNoUkyL9cq88Fx0e2qAFIIZ5cbj>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000222720.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000230144.tif
#   <id: 1G8YxLed8ce0VHrBteBjriz1ECyAUz3Kc>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000022272-0000230144.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000207872.tif
#   <id: 1vcBiRebBk_1K0fuO33vWpZH8VtDc1GN->
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000029696-0000207872.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000066816.tif
#   <id: 1q-1EZBUYjzUgZryiHWcB5OCiv7cksIy7>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000066816.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000111360.tif
#   <id: 1mU63hxUBictkSlWlrbR168MIONBCiT35>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000111360.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000170752.tif
#   <id: 1nfAH_lERRpfqNstd0jRxOP5hiPJLJcRR>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000170752.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000207872.tif
#   <id: 1urPs8OOri7TD-UH2UtMG38Tutq2rOcUu>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000037120-0000207872.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000014848.tif
#   <id: 16cV6hygxwcHJxEFDSZPpg9D5LviClXsw>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000014848.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000022272.tif
#   <id: 1FCiLb2hWsfutHEUPn2So9CIn1nIpeLrR>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000044544-0000022272.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000000000.tif
#   <id: 1Ij9hjYEl3YgQr2382zxy78AtAkfcCIjL>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000000000.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000007424.tif
#   <id: 1l4jisRO3H92ed5suxePOYDUFKO0JfpS7>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000051968-0000007424.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000029696.tif
#   <id: 1nBeMplrbDWClMO2cfTZ5qKZfX4AWreeR>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000029696.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000037120.tif
#   <id: 1kz-5_QfnIVwQTS4gmtFHOSIO4f9LvEHv>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000059392-0000037120.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000029696.tif
#   <id: 1k9W17_lBBkgA1cOWeJbQzeGe6osFIjOr>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000029696.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000066816.tif
#   <id: 1u8IeFM0nAmBsQMvsTaw-xb1fquBsEDjz>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000066816.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000126208.tif
#   <id: 1_8Blhf5vM-hH8lPj4lEElIwm04dzHbmM>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000126208.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000193024.tif
#   <id: 147mrf3tqDt03bArlLLM7LanwbkL0eJ8g>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000193024.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000200448.tif
#   <id: 1Wf_oo0v2sRtn8DY7y05PleZouJB1skH1>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000066816-0000200448.tif
#
# File downloaded:
#
# • Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000222720.tif
#   <id: 1KLCjkT__5mZRpDNe3BZgJq-1apVKzh40>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Oahu_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000074240-0000222720.tif
#
# File downloaded:
#
# • Niihau_Average_Land_Cover_Buffer_2000m_2015_to_2019.tif
#   <id: 1ZYHaUPRb63bqQlozlGROcE2i-X6azXKO>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Niihau_Average_Land_Cover_Buffer_2000m_2015_to_2019.tif
#
# File downloaded:
#
# • Hawaii_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000007424.tif
#   <id: 1uhKYUQRbWdiPnWb6Amlh-LH4HokS4pN3>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Hawaii_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000014848-0000007424.tif
#
# File downloaded:
#
# • Maui_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000007424.tif
#   <id: 1WFNl6QYTWSeR_I717A_59YO3yAuG16H2>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Maui_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000007424.tif
#
# File downloaded:
#
# • Hawaii_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000014848.tif
#   <id: 1YUi_QqYNKZlRenhertBHdt7DWKBOn8Vp>
#
# Saved locally as:
#
# • /content/predictor_variables/DynamicWorld_landcover/Hawaii_Average_Land_Cover_Buffer_2000m_2015_to_2019-0000000000-0000014848.tif

# %%
  # https://drive.google.com/file/d/1ryTzWz0t9mgI5ynPvMzM21D135dLJvWv/view?usp=drive_link
  # Updated: https://drive.google.com/file/d/17c3DJcujQ_0MHirG2z2lSU88A0lvjo1C/view?usp=sharing
drive_download(as_id('17c3DJcujQ_0MHirG2z2lSU88A0lvjo1C'), path = paste0('/content/fia.csv'), overwrite = TRUE)
fia_dt <-  st_read('/content/fia.csv') %>% st_as_sf(coords = c("LON","LAT"), crs = 4326) %>% data.table

# %%
fia_dt[,Stock_SOC_Mg_Ha :=  Stock_SOC_Mg_Ha %>% as.numeric,]

# %%
(fia_dt %>% st_as_sf)[,'Stock_SOC_Mg_Ha' ] %>% plot

# %%
dir_list <- list.dirs('/content/predictor_variables')[-1]

names(dir_list) <- list.dirs('/content/predictor_variables',full.names = FALSE)[-1]

# %%
names(dir_list) %>% lapply(function(x){
  print(x)
 y <- dir_list[[x]]
 vrt(y %>% lapply(function(x){list.files(y, pattern='*.tif',full.names = T)}) %>%unlist,filename=paste0(y,'/',x,'.vrt'),overwrite=T)
 print(paste('Done',x))
})

# %%
 raster_list <- list.files('/content/predictor_variables',pattern = '*.vrt',full.names = T,recursive = T) %>% lapply(stack) %>% lapply(rast)

raster_list
  # # Use gdalbuildvrt to create VRT
  # gdalbuildvrt(destfile = paste0(x,'/',x,'.vrt'),
  #              files =   (x %>% lapply(function(x){list.files(x, pattern='*.tif',full.names = T)})),
  #              separate = FALSE, # Change to TRUE if you want separate bands
  #              overwrite = TRUE)
# Out:
# [[1]]
# class       : SpatRaster
# dimensions  : 371833, 2204931, 10  (nrow, ncol, nlyr)
# resolution  : 9.031842e-05, 9.031842e-05  (x, y)
# extent      : -178.4436, 20.70229, 18.8654, 52.44877  (xmin, xmax, ymin, ymax)
# coord. ref. : +proj=longlat +datum=WGS84 +no_defs
# source      : DynamicWorld_landcover.vrt
# names       : Dynam~ver_1, Dynam~ver_2, Dynam~ver_3, Dynam~ver_4, Dynam~ver_5, Dynam~ver_6, ...
#
# [[2]]
# class       : SpatRaster
# dimensions  : 35816, 87898, 1  (nrow, ncol, nlyr)
# resolution  : 0.0002694946, 0.0002694946  (x, y)
# extent      : -178.4436, -154.7556, 18.8652, 28.51742  (xmin, xmax, ymin, ymax)
# coord. ref. : +proj=longlat +datum=WGS84 +no_defs
# source      : Elevation.vrt
# name        : Elevation
#
# [[3]]
# class       : SpatRaster
# dimensions  : 80530, 270460, 1  (nrow, ncol, nlyr)
# resolution  : 0.0002694946, 0.0002694946  (x, y)
# extent      : -178.4437, -105.5562, 18.86543, 40.56783  (xmin, xmax, ymin, ymax)
# coord. ref. : +proj=longlat +datum=WGS84 +no_defs
# source      : LandForms.vrt
# name        : LandForms
#
# [[4]]
# class       : SpatRaster
# dimensions  : 35815, 87898, 7  (nrow, ncol, nlyr)
# resolution  : 0.0002694946, 0.0002694946  (x, y)
# extent      : -178.4437, -154.7556, 18.86543, 28.51738  (xmin, xmax, ymin, ymax)
# coord. ref. : +proj=longlat +datum=WGS84 +no_defs
# source      : LandSat_composite.vrt
# names       : LandS~ite_1, LandS~ite_2, LandS~ite_3, LandS~ite_4, LandS~ite_5, LandS~ite_6, ...
#
# [[5]]
# class       : SpatRaster
# dimensions  : 11939, 29300, 1  (nrow, ncol, nlyr)
# resolution  : 0.0008084838, 0.0008084838  (x, y)
# extent      : -178.4437, -154.7551, 18.86516, 28.51765  (xmin, xmax, ymin, ymax)
# coord. ref. : +proj=longlat +datum=WGS84 +no_defs
# source      : SRTM_mTPI.vrt
# name        : SRTM_mTPI
#
# [[6]]
# class       : SpatRaster
# dimensions  : 1075, 2638, 14  (nrow, ncol, nlyr)
# resolution  : 0.008983153, 0.008983153  (x, y)
# extent      : -178.4503, -154.7528, 18.86462, 28.52151  (xmin, xmax, ymin, ymax)
# coord. ref. : +proj=longlat +datum=WGS84 +no_defs
# source      : TerraClimate.vrt
# names       : Terra~ate_1, Terra~ate_2, Terra~ate_3, Terra~ate_4, Terra~ate_5, Terra~ate_6, ...

# %%
gedi_dt <- st_read('/content/predictor_variables/Hawaii_GEDI_4A.gpkg') %>% data.table()
# Out:
# Reading layer `Hawaii_GEDI_2' from data source
#   `/content/predictor_variables/Hawaii_GEDI_4A.gpkg' using driver `GPKG'
# Integer64 values larger than 9.0072e+15 lost significance after conversion to double;
# use argument int64_as_string = TRUE to import them lossless, as character
# Simple feature collection with 4839466 features and 28 fields
# Geometry type: POINT
# Dimension:     XY
# Bounding box:  xmin: -160.6006 ymin: 18.86556 xmax: -154.7559 ymax: 22.28996
# Geodetic CRS:  WGS 84

# %%
grid_dt <- st_read('/content/predictor_variables/HI_island_250_m_grid.gpkg') %>% data.table()
# Out:
# Reading layer `grid' from data source
#   `/content/predictor_variables/HI_island_250_m_grid.gpkg' using driver `GPKG'
# Simple feature collection with 263630 features and 5 fields
# Geometry type: POINT
# Dimension:     XY
# Bounding box:  xmin: 57161.36 ymin: 8702.317 xmax: 572661.4 ymax: 381202.3
# Projected CRS: NAD_1983_HARN_StatePlane_Hawaii_1_FIPS_5101

# %%
fia_dt[,c('Stock_SOC_Mg_Ha','geometry')]$Stock_SOC_Mg_Ha %>% qplot
# Out:
# Warning message:
# “`qplot()` was deprecated in ggplot2 3.4.0.”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# Warning message:
# “Removed 1 rows containing non-finite values (`stat_bin()`).”
# plot without title

# %%
grid_int_dt <- fia_dt[,c('PLOT','Stock_SOC_Mg_Ha','geometry')] %>% st_as_sf() %>% st_transform(4135) %>% st_buffer(10000) %>% st_transform(4326) %>% st_intersects(grid_dt %>% st_as_sf %>% st_transform(4326))

# %%
  dummy_geom <- fia_dt %>% st_as_sf() %>% st_transform(4135) %>% st_buffer(1000) %>% st_transform(4326)
  fia_dt$dummy_geom <- dummy_geom$geometry

  example_poly <- (fia_dt %>%data.table)[,c('PLOT','Stock_SOC_Mg_Ha','dummy_geom')]

  ls_dt <- data.table(exact_extract(raster_list[[4]],example_poly %>% st_as_sf,'mean') %>% data.table)
  names(ls_dt) <- c("ultra_blue", "blue", "green", "red", "infrared", "sw1", "sw2")

  climate_dt <- data.table(exact_extract(raster_list[[6]],example_poly %>% st_as_sf,'mean') %>% data.table)
  names(climate_dt) <- c("aet", "def", "pdsi", "pet", "pr", "ro", "soil", "srad", "swe", "tmmn", "tmmx", "vap", "vpd", "vs")

  elevation_dt <- data.table(exact_extract(raster_list[[2]],example_poly %>% st_as_sf,'mean') %>% data.table)
  names(elevation_dt) <- c("elevation")

  rf_dt <- data.table(example_poly,ls_dt,climate_dt,elevation_dt)
# Out:
# Cannot preload entire working area of 1469849220 cells with max_cells_in_memory = 3e+07. Raster values will be read for each feature individually.
#   |======================================================================| 100%
#   |======================================================================| 100%
# Cannot preload entire working area of 209978460 cells with max_cells_in_memory = 3e+07. Raster values will be read for each feature individually.
#   |======================================================================| 100%

# %%
rf_dt %>%
  ggplot(aes(x=vs,y=Stock_SOC_Mg_Ha))+
  geom_point()
# Out:
# Warning message:
# “Removed 20 rows containing missing values (`geom_point()`).”
# plot without title

# %%
detectCores()
# Out:
# [1] 8

# %%
cl <- makeCluster(1)

# %%
parallel::detectCores(all.tests = FALSE, logical = TRUE)
# Out:
# [1] 8

# %%
grid_int_unique <- grid_int_dt %>% unlist %>% unique

# %%
grid_int_unique[1]
# Out:
# [1] 129928

# %%
grid_dt[grid_int_unique] %>% st_as_sf %>% st_write('grid_dt.gpkg')
# Out:
# Writing layer `grid_dt' to data source `grid_dt.gpkg' using driver `GPKG'
# Writing 227561 features with 5 fields and geometry type Point.

# %%
  example_poly <- grid_dt[grid_int_unique] %>% st_as_sf %>% st_transform(4135) %>% st_buffer(250) %>% st_transform(4326)

# %%
  # example_poly <- (fia_extended_dt %>%data.table)[,c('PLOT','Stock_SOC_Mg_Ha','dummy_geom')]

  cover_dt <- data.table(exact_extract(raster_list[[1]],example_poly %>% st_as_sf,'mean',progress = TRUE) %>% data.table)
  names(cover_dt) <- c("water", "trees", "grass", "flooded_vegetation", "crops", "shrub_and_scrub", "built", "bare", "snow_and_ice",'max')

  elevation_dt <- data.table(exact_extract(raster_list[[2]],example_poly %>% st_as_sf,'mean',progress = TRUE) %>% data.table)
  names(elevation_dt) <- c("elevation")

  landform_dt <- data.table(exact_extract(raster_list[[3]],example_poly %>% st_as_sf,'mode',progress = TRUE) %>% data.table)
  names(landform_dt) <- c("landform")

  ls_dt <- data.table(exact_extract(raster_list[[4]],example_poly %>% st_as_sf,'mean',progress = TRUE) %>% data.table)
  names(ls_dt) <- c("ultra_blue", "blue", "green", "red", "infrared", "sw1", "sw2")

  tpi_dt <- data.table(exact_extract(raster_list[[5]],example_poly %>% st_as_sf,'mean',progress = TRUE) %>% data.table)
  names(tpi_dt) <- c("SRTM_mTPI")

  climate_dt <- data.table(exact_extract(raster_list[[6]],example_poly %>% st_as_sf,'mean',progress = TRUE) %>% data.table)
  names(climate_dt) <- c("aet", "def", "pdsi", "pet", "pr", "ro", "soil", "srad", "swe", "tmmn", "tmmx", "vap", "vpd", "vs")
# Out:
# Cannot preload entire working area of 19845102660 cells with max_cells_in_memory = 3e+07. Raster values will be read for each feature individually.
#   |======================================================================| 100%
# Cannot preload entire working area of 222908182 cells with max_cells_in_memory = 3e+07. Raster values will be read for each feature individually.
#   |======================================================================| 100%
# Cannot preload entire working area of 222908182 cells with max_cells_in_memory = 3e+07. Raster values will be read for each feature individually.
#   |======================================================================| 100%
# Cannot preload entire working area of 1560357274 cells with max_cells_in_memory = 3e+07. Raster values will be read for each feature individually.
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%

# %%
  rf_dt <- data.table(example_poly,cover_dt,elevation_dt,landform_dt,tpi_dt,climate_dt)

# %%
  rf_dt$geom <- grid_dt[grid_int_unique]$geom

# %%
rf_dt %>% st_as_sf %>% st_write('250_summary_grid_dt.gpkg')
# Out:
# Writing layer `250_summary_grid_dt' to data source
#   `250_summary_grid_dt.gpkg' using driver `GPKG'
# Writing 227561 features with 32 fields and geometry type Point.

# %%
# Assuming 'cl' is your cluster object and the variables you want to export are
# fia_dt, grid_dt, grid_int_dt, and raster_list

# List of variables to be exported to the cluster
varlist <- c("fia_dt", "grid_dt", "grid_int_dt", "raster_list")

# Export the variables
clusterExport(cl = cl, varlist = varlist)

# %%
clusterEvalQ(cl, {
  library(sf)
  library(magrittr)
  library(data.table)
  library(raster)
  library(exactextractr)
  library(terra)
  library(randomForest)
})
# Out:
# [[1]]
#  [1] "randomForest"  "terra"         "exactextractr" "raster"
#  [5] "sp"            "data.table"    "magrittr"      "sf"
#  [9] "stats"         "graphics"      "grDevices"     "utils"
# [13] "datasets"      "methods"       "base"

# %%
# This function will return a logical indicating if all variables are available on each node
clusterEvalQ(cl, {
  all(c("fia_dt", "grid_dt", "grid_int_dt", "raster_list") %in% ls())
})
# Out:
# [[1]]
# [1] TRUE

# %%
# Check memory limit on workers
clusterEvalQ(cl, memory.limit())
# Out:
# [[1]]
# [1] Inf

# %%
clusterEvalQ(cl, options(error = recover))
# Out:
# [[1]]
# [[1]]$error
# NULL

# %%
install.packages('doParallel')
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘foreach’, ‘iterators’

# %%
library(doParallel)
library(foreach)

# Set up the cluster
cl <- makeCluster(detectCores() - 1) # reserve one core for system processes
registerDoParallel(cl)

# Export the variables and functions to the cluster
clusterExport(cl, varlist=c("fia_dt", "grid_dt", "grid_int_dt", "raster_list"))
clusterEvalQ(cl, {
  library(sf)
  library(magrittr)
  library(data.table)
  library(raster)
  library(exactextractr)
  library(terra)
  library(randomForest)
})
# Out:
# Loading required package: foreach
#
# Loading required package: iterators
# [[1]]
#  [1] "randomForest"  "terra"         "exactextractr" "raster"
#  [5] "sp"            "data.table"    "magrittr"      "sf"
#  [9] "stats"         "graphics"      "grDevices"     "utils"
# [13] "datasets"      "methods"       "base"
#
# [[2]]
#  [1] "randomForest"  "terra"         "exactextractr" "raster"
#  [5] "sp"            "data.table"    "magrittr"      "sf"
#  [9] "stats"         "graphics"      "grDevices"     "utils"
# [13] "datasets"      "methods"       "base"
#
# [[3]]
#  [1] "randomForest"  "terra"         "exactextractr" "raster"
#  [5] "sp"            "data.table"    "magrittr"      "sf"
#  [9] "stats"         "graphics"      "grDevices"     "utils"
# [13] "datasets"      "methods"       "base"
#
# [[4]]
#  [1] "randomForest"  "terra"         "exactextractr" "raster"
#  [5] "sp"            "data.table"    "magrittr"      "sf"
#  [9] "stats"         "graphics"      "grDevices"     "utils"
# [13] "datasets"      "methods"       "base"
#
# [[5]]
#  [1] "randomForest"  "terra"         "exactextractr" "raster"
#  [5] "sp"            "data.table"    "magrittr"      "sf"
#  [9] "stats"         "graphics"      "grDevices"     "utils"
# [13] "datasets"      "methods"       "base"
#
# [[6]]
#  [1] "randomForest"  "terra"         "exactextractr" "raster"
#  [5] "sp"            "data.table"    "magrittr"      "sf"
#  [9] "stats"         "graphics"      "grDevices"     "utils"
# [13] "datasets"      "methods"       "base"
#
# [[7]]
#  [1] "randomForest"  "terra"         "exactextractr" "raster"
#  [5] "sp"            "data.table"    "magrittr"      "sf"
#  [9] "stats"         "graphics"      "grDevices"     "utils"
# [13] "datasets"      "methods"       "base"

# %%
sim_dt <-
1:1000 %>% lapply(.,function(m,fia_dt,grid_dt,grid_int_dt,raster_list){

  # library(ggplot2)
  library(sf)
  library(magrittr)
  library(data.table)
  library(raster)
  library(exactextractr)
  # library(googledrive)
  # library(DBI)
  library(terra)
  library(randomForest)
  # library(parallel)
  extension <- 1
  fia_extended_dt <- fia_dt

  dummy_geom <- grid_dt[grid_int_dt %>% lapply(function(x){sample(x,extension)}) %>% unlist,] %>% st_as_sf() %>% st_transform(4135) %>% st_buffer(250) %>% st_transform(4326)
  fia_extended_dt$dummy_geom <- dummy_geom$geom

  example_poly <- (fia_extended_dt %>%data.table)[,c('PLOT','Stock_SOC_Mg_Ha','dummy_geom')]

  cover_dt <- data.table(exact_extract(raster_list[[1]],example_poly %>% st_as_sf,'mean',progress = FALSE) %>% data.table)
  names(cover_dt) <- c("water", "trees", "grass", "flooded_vegetation", "crops", "shrub_and_scrub", "built", "bare", "snow_and_ice",'max')

  elevation_dt <- data.table(exact_extract(raster_list[[2]],example_poly %>% st_as_sf,'mean',progress = FALSE) %>% data.table)
  names(elevation_dt) <- c("elevation")

  landform_dt <- data.table(exact_extract(raster_list[[3]],example_poly %>% st_as_sf,'mode',progress = FALSE) %>% data.table)
  names(landform_dt) <- c("landform")

  ls_dt <- data.table(exact_extract(raster_list[[4]],example_poly %>% st_as_sf,'mean',progress = FALSE) %>% data.table)
  names(ls_dt) <- c("ultra_blue", "blue", "green", "red", "infrared", "sw1", "sw2")

  tpi_dt <- data.table(exact_extract(raster_list[[5]],example_poly %>% st_as_sf,'mean',progress = FALSE) %>% data.table)
  names(tpi_dt) <- c("SRTM_mTPI")

  climate_dt <- data.table(exact_extract(raster_list[[6]],example_poly %>% st_as_sf,'mean',progress = FALSE) %>% data.table)
  names(climate_dt) <- c("aet", "def", "pdsi", "pet", "pr", "ro", "soil", "srad", "swe", "tmmn", "tmmx", "vap", "vpd", "vs")



  rf_dt <- data.table(example_poly,cover_dt,elevation_dt,landform_dt,tpi_dt,climate_dt)

  # rf_dt %>% head
  x_var <- (rf_dt %>% names)[-c(1,2,3)]

  rf_form <- as.formula(paste0('Stock_SOC_Mg_Ha~',paste(x_var,collapse = '+')))

  # print(rf_form)

  rf_dt <- rf_dt[complete.cases(rf_dt[,-3]),]

  rf_terra <- randomForest(rf_form,rf_dt,verbose=T)

  rf_imp_dt <- rf_terra$importance %>% t %>% data.table

  names(rf_imp_dt) <-paste0('var_imp_',names(rf_imp_dt))
  # [,c('PLOT','C_TOTAL_PCT','geom')]
  out_dt <- data.table(rf_dt,data.table(predicted = rf_terra$predicted),rf_imp_dt[rep(1,nrow(rf_dt)),])

  return(out_dt)
  },fia_dt,grid_dt,grid_int_dt,raster_list) %>%
  rbindlist

# %%
# Write to GeoPackage
sim_dt %>% st_write("/content/sim_results_Full_Run1.gpkg", append=FALSE)

# %%
# https://drive.google.com/drive/folders/1uVZCzCb5gRE8wfZckspRuKz1TQd5LpeM?usp=drive_link
drive_upload("/content/sim_results_Full_Run1.gpkg", path = as_id("1uVZCzCb5gRE8wfZckspRuKz1TQd5LpeM"))

# %%
# sim_dt

# %%
sim_dt %>%
  ggplot(aes(y=Stock_SOC_Mg_Ha,x=predicted))+
    geom_point()

# %%
# Load the necessary library
library(repr)

# Adjust width and height of plots
options(repr.plot.width=20, repr.plot.height=8)

# %%
# for(i in 1:10){

sim_dt[,residual := predicted-Stock_SOC_Mg_Ha]

sim_dt[,residual_per := residual/Stock_SOC_Mg_Ha]

samp_dt <- sim_dt[residual_per>-.05 &residual_per <.05]
plot <- sample(samp_dt$PLOT,1)
# print(plot)
(samp_dt[PLOT==plot] %>% melt(id.vars = c('PLOT','Stock_SOC_Mg_Ha','dummy_geom','water','trees','grass','flooded_vegetation','crops','shrub_and_scrub','built','bare','snow_and_ice','max','elevation','landform','SRTM_mTPI','aet','def','pdsi','pet','pr','ro','soil','srad','swe','tmmn','tmmx','vap','vpd','vs','predicted','residual','residual_per')) %>%
  ggplot(aes(x=variable,y=value))+
  geom_boxplot() )%>% plot
# }

# %%
dummy_geom <- grid_dt[grid_int_dt %>% lapply(function(x){sample(x,1)}) %>% unlist,] %>% st_as_sf() %>% st_transform(4135) %>% st_buffer(2500) %>% st_transform(4326)

# %%
fia_dt$dummy_geom <- dummy_geom$geom

# %%
example_poly <- (fia_dt %>%data.table)[,c('C_TOTAL_PCT','dummy_geom')]

# %%
rf_dt <- data.table(example_poly,exact_extract(raster_list[[6]],example_poly %>% st_as_sf,'mean') %>% data.table)

# %%
# rf_dt

# %%
names(rf_dt)[-c(1,2)] <- c("aet", "def", "pdsi", "pet", "pr", "ro", "soil", "srad", "swe", "tmmn", "tmmx", "vap", "vpd", "vs")

# %%
rf_form <- as.formula(paste0('Stock_SOC_Mg_Ha~',paste((rf_dt %>% names)[-c(1,2)],collapse = '+')))
rf_form

# %%
rf_terra <- randomForest(rf_form,rf_dt[complete.cases(rf_dt[,-2]),],verbose=T)
rf_terra %>% varImpPlot
rf_terra

# %%
data.frame(field = rf_terra$y,predicted = rf_terra$predicted) %>%
  ggplot(aes(x=predicted,y=field))+
  geom_point()
